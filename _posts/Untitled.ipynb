# %%
import pandas as pd
import numpy as np

dicty = {"nb":(3,5,10),
         "price": (15,25,50)}
df = pd.DataFrame(dicty)

# %%
df
# Out:
#    nb  price
# 0   3     15
# 1   5     25
# 2  10     50

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df.nb,df.price,marker="x",color="blue",s=60)
plt.xlim((0,11))
plt.ylim((0,55))
plt.xlabel("Number of pints")
plt.ylabel("Price in pounds")
plt.show()

# %%
plt.scatter(df.nb,df.price,marker="x",color="blue",s=60)
plt.plot([0,11],[0,55],'k--',color="red")
plt.xlim((0,11))
plt.ylim((0,55))
plt.xlabel("Number of pints")
plt.ylabel("Price in pounds")
plt.show()
